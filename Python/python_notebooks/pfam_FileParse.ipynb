# %%
outfile = open("C:\\Users\\Bilal\\Desktop\\pfam\\PfamOUT1.txt", "w")
file = open("C:\\Users\\Bilal\\Desktop\\pfam\\Pfam-uniprot_All.tab", "r")
for line in file.readlines():
    
    line = line.split("	")
    if line[1].find("PF") != -1:
        pfterm = line[1].strip(";\n")
        #pfterm = pfterm.split(";")
               
        #fw.write(line[0] + "\t" + goterm + "\n")
        print(line[0] + "\t" + pfterm + "\n")
        outfile.write(line[0] + "\t" + pfterm + "\n")
    #print(line)
# Out:
# Q9Y3L3	PF03114;PF00620
#
# P04217	PF13895
#
# Q5SQ80	PF12796
#
# Q4UJ75	PF12796
#
# A0PJZ0	PF00023;PF12796
#
# P01023	PF00207;PF07678;PF01835;PF07703;PF07677;PF10569
#
# A8K2U0	PF00207;PF07678;PF01835;PF07703;PF07677;PF10569
#
# Q9NPC4	PF04572;PF04488
#
# P05067	PF10515;PF12924;PF12925;PF02177;PF03494;PF00014
#
# Q9NRG9	PF00400
#
# Q86V21	PF16177;PF00501
#
# Q8N5Z0	PF00155
#
# Q5VST6	PF12146
#
# Q6PCB6	PF12146
#
# O00590	PF00001
#
# P11229	PF00001
#
# P20309	PF00001
#
# Q8TDX5	PF04909
#
# Q9NPJ3	PF03061
#
# O14672	PF00200;PF01562
#
# O75078	PF08516;PF00200;PF07974;PF01562;PF01421
#
# Q9Y3Q7	PF08516;PF00200;PF01562;PF01421
#
# Q6DHV7	PF00962
#
# Q99965	PF08516;PF00200;PF01562;PF01421
#
# O75689	PF01412;PF00169
#
# Q9NPF8	PF01412;PF00169
#
# O00116	PF02913;PF01565
#
# Q9BUB4	PF02137
#
# Q86TW2	PF03109
#
# Q7Z695	PF03109
#
# Q6P093	PF07859
#
# Q5VUY0	PF07859
#
# Q5VUY2	PF07859
#
# O60503	PF00211
#
# Q96PN6	PF00211
#
# Q9UEY8	PF00596
#
# Q8N7X0	PF00648
#
# P11766	PF08240;PF00107
#
# ...

# %%
outfile = open("C:\\Users\\Bilal\\Desktop\\pfam\\PfamOUT2.txt", "w")
file = open("C:\\Users\\Bilal\\Desktop\\pfam\\PfamOUT1.txt", "r")

for line in file.readlines():
    line = line.strip()
    line = line.split("\t")
    pf = line[1].split(";")
    for pfterm in pf:
        print(line[0] +"\t"+ pfterm + "\n")
        outfile.write(line[0] + "\t" + pfterm + "\n")
# Out:
# Q9Y3L3	PF03114
#
# Q9Y3L3	PF00620
#
# P04217	PF13895
#
# Q5SQ80	PF12796
#
# Q4UJ75	PF12796
#
# A0PJZ0	PF00023
#
# A0PJZ0	PF12796
#
# P01023	PF00207
#
# P01023	PF07678
#
# P01023	PF01835
#
# P01023	PF07703
#
# P01023	PF07677
#
# P01023	PF10569
#
# A8K2U0	PF00207
#
# A8K2U0	PF07678
#
# A8K2U0	PF01835
#
# A8K2U0	PF07703
#
# A8K2U0	PF07677
#
# A8K2U0	PF10569
#
# Q9NPC4	PF04572
#
# Q9NPC4	PF04488
#
# P05067	PF10515
#
# P05067	PF12924
#
# P05067	PF12925
#
# P05067	PF02177
#
# P05067	PF03494
#
# P05067	PF00014
#
# Q9NRG9	PF00400
#
# Q86V21	PF16177
#
# Q86V21	PF00501
#
# Q8N5Z0	PF00155
#
# Q5VST6	PF12146
#
# Q6PCB6	PF12146
#
# O00590	PF00001
#
# P11229	PF00001
#
# P20309	PF00001
#
# Q8TDX5	PF04909
#
# Q9NPJ3	PF03061
#
# O14672	PF00200
#
# O14672	PF01562
#
# O75078	PF08516
#
# O75078	PF00200
#
# O75078	PF07974
#
# O75078	PF01562
#
# O75078	PF01421
#
# Q9Y3Q7	PF08516
#
# Q9Y3Q7	PF00200
#
# Q9Y3Q7	PF01562
#
# Q9Y3Q7	PF01421
#
# Q6DHV7	PF00962
#
# Q99965	PF08516
#
# Q99965	PF00200
#
# ...
